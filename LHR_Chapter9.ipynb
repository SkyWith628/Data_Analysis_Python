# %% [markdown]
# [LHR 코드 9-1]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 리스트에 데이터 삽입하기
X = [1, 2, 3, 4, 5]
Y_linear = [2, 4, 6, 8, 10]  # 선형 데이터

# 리스트를 데이터프레임으로 변환하기
data = {'X': X, 'Y_선형': Y_linear}
df = pd.DataFrame(data)
df
# Out:
#    X  Y_선형
# 0  1     2
# 1  2     4
# 2  3     6
# 3  4     8
# 4  5    10

# %% [markdown]
# [LHR 코드 9-2]

# %%
import matplotlib.pyplot as plt

# 그래프 그리기
df.plot(x='X', y='Y')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2041212525.py in <cell line: 0>()
#       2
#       3 # 그래프 그리기
# ----> 4 df.plot(x='X', y='Y')
#       5 plt.show()
#
# ...

# %% [markdown]
# [LHR 코드 9-3]

# %%
# 피어슨 상관분석 수행하기 (X와 Y선형)
coef_p = df.corr(method='pearson')
print("피어슨 상관계수 (X와 Y_linear):")
print(coef_p)

# 스피어만 상관분석
# 스피어만 상관분석 수행하기 (X와 Y선형)
coef_s = df.corr(method='spearman')
print("\n스피어만 상관계수 (X와 Y_linear):")
print(coef_s)

# 켄달 상관분석
# 켄달 상관분석 수행하기 (X와 Y선형)
coef_k = df.corr(method='kendall')
print("\n켄달 상관계수 (X와 Y_linear):")
print(coef_k)
# Out:
# 피어슨 상관계수 (X와 Y_linear):
#         X  Y_선형
# X     1.0   1.0
# Y_선형  1.0   1.0
#
# 스피어만 상관계수 (X와 Y_linear):
#         X  Y_선형
# X     1.0   1.0
# Y_선형  1.0   1.0
#
# 켄달 상관계수 (X와 Y_linear):
#         X  Y_선형
# X     1.0   1.0
# Y_선형  1.0   1.0

# %% [markdown]
# [LHR 코드 9-4]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 리스트에 데이터 삽입하기
X = [1, 2, 3, 4, 5]
Y_nonlinear = [10, 9, 7, 5, 3]  # 비선형 데이터

# 리스트를 데이터프레임으로 변환하기
data = {'X': X, 'Y_비선형': Y_nonlinear}
df = pd.DataFrame(data)
df

# 그래프 그리기
df.plot(x='X', y='Y_비선형')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# [LHR 코드 9-5]

# %%
# 피어슨 상관분석 수행하기 (XY비선형)
coef_p = df.corr(method='pearson')
print("피어슨 상관계수 (XY비선형):")
print(coef_p)

# 스피어만 상관분석 수행하기 (XY비선형)
coef_s = df.corr(method='spearman')
print("\n스피어만 상관계수 (XY비선형):")
print(coef_s)

# 켄달 상관분석 수행하기 (XY비선형)
coef_k = df.corr(method='kendall')
print("\n켄달 상관계수 (XY비선형):")
print(coef_k)
# Out:
# 피어슨 상관계수 (XY비선형):
#               X     Y_비선형
# X      1.000000 -0.993884
# Y_비선형 -0.993884  1.000000
#
# 스피어만 상관계수 (XY비선형):
#          X  Y_비선형
# X      1.0   -1.0
# Y_비선형 -1.0    1.0
#
# 켄달 상관계수 (XY비선형):
#          X  Y_비선형
# X      1.0   -1.0
# Y_비선형 -1.0    1.0

# %% [markdown]
# [LHR 코드 9-6]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 리스트에 데이터 삽입하기
X = [1, 2, 3, 4, 5]
Y_nonlinear = [10, 9, 7, 7, 3]  # 비선형 데이터

# 리스트를 데이터프레임으로 변환하기
data = {'X': X, 'Y_비선형': Y_nonlinear}
df = pd.DataFrame(data)
df

# 그래프 그리기
df.plot(x='X', y='Y_비선형')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# [LHR 코드 9-7]

# %%
# 피어슨 상관분석 수행하기 (XY비선형)
coef_p = df.corr(method='pearson')
print("피어슨 상관계수 (XY비선형):")
print(coef_p)

# 스피어만 상관분석 수행하기 (XY비선형)
coef_s = df.corr(method='spearman')
print("\n스피어만 상관계수 (XY비선형-동점):")
print(coef_s)

# 켄달 상관분석 수행하기 (XY비선형)
coef_k = df.corr(method='kendall')
print("\n켄달 상관계수 (XY비선형-동점):")
print(coef_k)
# Out:
# 피어슨 상관계수 (XY비선형):
#               X     Y_비선형
# X      1.000000 -0.942809
# Y_비선형 -0.942809  1.000000
#
# 스피어만 상관계수 (XY비선형-동점):
#               X     Y_비선형
# X      1.000000 -0.974679
# Y_비선형 -0.974679  1.000000
#
# 켄달 상관계수 (XY비선형-동점):
#               X     Y_비선형
# X      1.000000 -0.948683
# Y_비선형 -0.948683  1.000000

# %% [markdown]
# [LHR 코드 9-8]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 리스트에 데이터 삽입하기
X = [1, 2, 3, 4]
Y = [10, 9, 8, 7]

# 리스트를 데이터프레임으로 변환하기
data = {'XA': X, 'YA': Y}
df = pd.DataFrame(data)
df

# 그래프 그리기
df.plot(x='XA', y='YA')
plt.show()

# 피어슨 상관분석 수행하기 (A)
Acoef_p = df.corr(method='pearson')
print("피어슨 상관계수(A형):")
print(Acoef_p)

# 스피어만 상관분석 수행하기 (A)
Acoef_s = df.corr(method='spearman')
print("\n스피어만 상관계수(A형):")
print(Acoef_s)

# 켄달 상관분석 수행하기 (A)
Acoef_k = df.corr(method='kendall')
print("\n켄달 상관계수(A형):")
print(Acoef_k)
# Out:
# 피어슨 상관계수(A형):
#      XA   YA
# XA  1.0 -1.0
# YA -1.0  1.0
#
# 스피어만 상관계수(A형):
#      XA   YA
# XA  1.0 -1.0
# YA -1.0  1.0
#
# 켄달 상관계수(A형):
#      XA   YA
# XA  1.0 -1.0
# YA -1.0  1.0

# %% [markdown]
# [LHR 코드 9-9]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 리스트에 데이터 삽입하기
X = [1, 2, 3, 4]
Y = [10, 20, 30, 30]

# 리스트를 데이터프레임으로 변환하기
data = {'XB': X, 'YB': Y}
df = pd.DataFrame(data)
df

# 그래프 그리기
df.plot(x='XB', y='YB')
plt.show()

# 피어슨 상관분석 수행하기 (B)
Bcoef_p = df.corr(method='pearson')
print("피어슨 상관계수 (B형):")
print(Bcoef_p)

# 스피어만 상관분석 수행하기 (B)
Bcoef_s = df.corr(method='spearman')
print("\n스피어만 상관계수 (B형):")
print(Bcoef_s)

# 켄달 상관분석 수행하기 (B)
Bcoef_k = df.corr(method='kendall')
print("\n켄달 상관계수 (B형):")
print(Bcoef_k)
# Out:
# 피어슨 상관계수 (B형):
#          XB       YB
# XB  1.00000  0.94388
# YB  0.94388  1.00000
#
# 스피어만 상관계수 (B형):
#           XB        YB
# XB  1.000000  0.948683
# YB  0.948683  1.000000
#
# 켄달 상관계수 (B형):
#           XB        YB
# XB  1.000000  0.912871
# YB  0.912871  1.000000

# %% [markdown]
# [LHR 코드 9-10]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 리스트에 데이터 삽입하기
X = [1, 2, 3, 4]
Y = [30, 20, 35, 40]

# 리스트를 데이터프레임으로 변환하기
data = {'XC': X, 'YC': Y}
df = pd.DataFrame(data)
df

# 그래프 그리기
df.plot(x='XC', y='YC')
plt.show()

# 피어슨 상관분석 수행하기 (C)
Ccoef_p = df.corr(method='pearson')
print("피어슨 상관계수 (C형):")
print(Ccoef_p)

# 스피어만 상관분석 수행하기 (C)
Ccoef_s = df.corr(method='spearman')
print("\n스피어만 상관계수 (C형):")
print(Ccoef_s)

# 켄달 상관분석 수행하기 (C)
Ccoef_k = df.corr(method='kendall')
print("\n켄달 상관계수 (C형):")
print(Ccoef_k)
# Out:
# 피어슨 상관계수 (C형):
#           XC        YC
# XC  1.000000  0.680336
# YC  0.680336  1.000000
#
# 스피어만 상관계수 (C형):
#      XC   YC
# XC  1.0  0.8
# YC  0.8  1.0
#
# 켄달 상관계수 (C형):
#           XC        YC
# XC  1.000000  0.666667
# YC  0.666667  1.000000

# %% [markdown]
# [LHR 코드 9-11]

# %%
import pandas as pd

# 리스트에 데이터 삽입하기
engListening = [30, 60, 90]
engScore = [70, 80, 90]

# 리스트를 데이터프레임으로 변환하기
data = {'영어듣기': engListening, '영어점수': engScore}
df = pd.DataFrame(data)
df
# Out:
#    영어듣기  영어점수
# 0    30    70
# 1    60    80
# 2    90    90

# %% [markdown]
# [LHR 코드 9-12]

# %%
# 피어슨 상관분석 수행하기
coef_p = df.corr(method='pearson')
print(coef_p)

# 스피어만 상관분석 수행하기
coef_S = df.corr(method='spearman')
print(coef_S)

# 켄달 상관분석 수행하기
coef_k = df.corr(method='kendall')
print(coef_k)
# Out:
#       영어듣기  영어점수
# 영어듣기   1.0   1.0
# 영어점수   1.0   1.0
#       영어듣기  영어점수
# 영어듣기   1.0   1.0
# 영어점수   1.0   1.0
#       영어듣기  영어점수
# 영어듣기   1.0   1.0
# 영어점수   1.0   1.0

# %% [markdown]
# [LHR 코드 9-13]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 추가하기
engListening = [30, 60, 90, 31, 32, 69, 92, 99]
engScore = [70, 80, 90, 70, 71, 85, 90, 92]

data2 = {'영어듣기': engListening, '영어점수': engScore}
df2 = pd.DataFrame(data2)
df2
# Out:
#    영어듣기  영어점수
# 0    30    70
# 1    60    80
# 2    90    90
# 3    31    70
# 4    32    71
# 5    69    85
# 6    92    90
# 7    99    92

# %% [markdown]
# [LHR 코드 9-14]

# %%
import matplotlib.pyplot as plt

# 산점도 그래프의 x좌표와 y좌표 설정하기
plt.scatter(df2['영어듣기'], df2['영어점수'])
plt.show()

# %% [markdown]
# [LHR 코드 9-15]

# %%
# 피어슨 상관분석
coef = df2.corr(method='pearson')
print(coef)

# 스피어만 상관분석
spearmanCoef = df2.corr(method='spearman')
print(spearmanCoef)

# 켄달 상관분석
kendallCoef = df2.corr(method='kendall')
print(kendallCoef)
# Out:
#           영어듣기      영어점수
# 영어듣기  1.000000  0.995829
# 영어점수  0.995829  1.000000
#           영어듣기      영어점수
# 영어듣기  1.000000  0.988024
# 영어점수  0.988024  1.000000
#           영어듣기      영어점수
# 영어듣기  1.000000  0.963624
# 영어점수  0.963624  1.000000

# %% [markdown]
# [LHR 코드 9-16]

# %%
import pandas as pd

engListening = [30, 60, 90, 31, 32, 69, 92, 99]
engReading = [40, 45, 60, 20, 15, 70, 60, 80]
engClass = [60, 120, 120, 60, 60, 180, 120, 120]
engScore = [70, 80, 90, 70, 71, 85, 90, 92]

data3 = {'영어듣기': engListening, '영어독해': engReading, '영어수업': engClass, '영어점수': engScore}
df3 = pd.DataFrame(data3)
df3
# Out:
#    영어듣기  영어독해  영어수업  영어점수
# 0    30    40    60    70
# 1    60    45   120    80
# 2    90    60   120    90
# 3    31    20    60    70
# 4    32    15    60    71
# 5    69    70   180    85
# 6    92    60   120    90
# 7    99    80   120    92

# %% [markdown]
# [LHR 코드 9-17]

# %%
# 피어슨 상관분석
pearsonCoef = df3.corr(method='pearson')
print(pearsonCoef)

# 스피어만 상관분석
spearmanCoef = df3.corr(method='spearman')
print(spearmanCoef)

# 켄달 상관분석
kendallCoef = df3.corr(method='kendall')
print(kendallCoef)
# Out:
#           영어듣기      영어독해      영어수업      영어점수
# 영어듣기  1.000000  0.877201  0.703028  0.995829
# 영어독해  0.877201  1.000000  0.808755  0.894111
# 영어수업  0.703028  0.808755  1.000000  0.759453
# 영어점수  0.995829  0.894111  0.759453  1.000000
#           영어듣기      영어독해      영어수업      영어점수
# 영어듣기  1.000000  0.826362  0.717256  0.988024
# 영어독해  0.826362  1.000000  0.852757  0.848500
# 영어수업  0.717256  0.852757  1.000000  0.725950
# 영어점수  0.988024  0.848500  0.725950  1.000000
#           영어듣기      영어독해      영어수업      영어점수
# 영어듣기  1.000000  0.618284  0.563621  0.963624
# 영어독해  0.618284  1.000000  0.750568  0.679366
# 영어수업  0.563621  0.750568  1.000000  0.584898
# 영어점수  0.963624  0.679366  0.584898  1.000000

# %% [markdown]
# [LHR 코드 9-18]

# %%
from google.colab import files

# 파일 업로드 창을 띄우고, 선택된 파일을 업로드합니다.
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2b8b417b-d531-4ca2-adcd-1585a09148e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2b8b417b-d531-4ca2-adcd-1585a09148e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# [LHR 코드 9-19]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('LHR_nowon_transaction.csv', encoding='UTF-8')
df.head(7)
# Out:
#      data  money  house
# 0  22-Jan   1.25  117.0
# 1  22-Feb   1.25  203.0
# 2  22-Mar   1.25  275.0
# 3  22-Apr   1.50  227.0
# 4  22-May   1.75  338.0
# 5  22-Jun   1.75  312.0
# 6  22-Jul   2.25  300.0

# %% [markdown]
# [LHR 코드 9-20]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.scatter(df['house'], df['money'], color='blue', alpha=0.6)

plt.title('아파트별 거래금액 분포', fontsize=14)
plt.xlabel('아파트명')
plt.ylabel('거래금액(만원)')
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44144 (\N{HANGUL SYLLABLE GEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50529 (\N{HANGUL SYLLABLE AEG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from font(s) DejaVu Sans.
# ...

# %% [markdown]
# [LHR 코드 9-21]

# %%
coef = df[['money', 'house']].corr(method='pearson')
print(coef)
# Out:
#           money     house
# money  1.000000  0.464145
# house  0.464145  1.000000

# %% [markdown]
# [LHR 코드 9-22]

# %%
from google.colab import files

# 파일 업로드 창을 띄우고, 선택된 파일을 업로드합니다.
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b0e24be4-d555-47ff-b5bb-a737566c7b5b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b0e24be4-d555-47ff-b5bb-a737566c7b5b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# [LHR 코드 9-23]

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import csv

# %% [markdown]
# [LHR 코드 9-24]

# %%
# 데이터를 데이터프레임 형태로 읽어오기
df = pd.read_csv('LHR_gdp_population_data_utf8.csv', encoding='UTF-8')
df.head(7)
# Out:
#      국가  GDP 성장률     인구수
# 0    미국      0.9  334.00
# 1    일본      0.6  125.00
# 2    영국      0.4   67.53
# 3   프랑스      0.5   67.65
# 4    독일      1.1   83.16
# 5  이탈리아      1.7   59.24
# 6   캐나다      3.9   38.44

# %% [markdown]
# [LHR 코드 9-25]

# %%
df1 = df[['국가', 'GDP 성장률', '인구수']]
df1.columns = ['nation', 'GDP', 'population']
df1.head(3)
# Out:
#   nation  GDP  population
# 0     미국  0.9      334.00
# 1     일본  0.6      125.00
# 2     영국  0.4       67.53

# %% [markdown]
# [LHR 코드 9-26]

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.scatter(df1['population'], df1['GDP'])
plt.show()

# %% [markdown]
# [LHR 코드 9-27]

# %%
coef_P = df1[['population', 'GDP']].corr(method='pearson')
print(coef_P, '\n')

coef_S = df1[['population', 'GDP']].corr(method='spearman')
print(coef_S, '\n')

coef_K = df1[['population', 'GDP']].corr(method='kendall')
print(coef_K)
# Out:
#             population       GDP
# population    1.000000  0.198924
# GDP           0.198924  1.000000
#
#             population       GDP
# population    1.000000 -0.196388
# GDP          -0.196388  1.000000
#
#             population       GDP
# population    1.000000 -0.137568
# GDP          -0.137568  1.000000
