# %% [markdown]
# [코드 LHR 7-1]

# %%
# !pip install numpy;
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)

# %% [markdown]
# [코드 LHR 7-2]

# %%
import numpy as np

# 리스트를 생성하고 배열로 변환하기
list1 = [1, 2, 3, 4]
a = np.array(list1)

print('a.shape: ', a.shape)   # 배열의 차원(형태)을 출력
print('a[0]: ', a[0])         # 배열의 첫 번째 원소를 출력
# Out:
# a.shape:  (4,)
# a[0]:  1

# %% [markdown]
# [코드 LHR 7-3]

# %%
import numpy as np

# 2차원 배열 생성하기
b = np.array([[1, 2, 3], [4, 5, 6]])
print('b.shape: ', b.shape)
print('b[0,0]: ', b[0,0])
print('b[0]: ', b[0])   # 첫 번째 행
# Out:
# b.shape:  (2, 3)
# b[0,0]:  1
# b[0]:  [1 2 3]

# %% [markdown]
# [코드 LHR 7-4]

# %%
import numpy as np

# 1차원 배열 생성하기
b = np.arange(4)
print('b.shape:\n', b.shape)
print(b)
# Out:
# b.shape:
#  (4,)
# [0 1 2 3]

# %% [markdown]
# [코드 LHR 7-5]

# %%
import numpy as np

# 실수형 배열 생성하기
a = np.array([1, 2], dtype=np.float64)
print(a.dtype)
print('a\n', a)

# 정수형 배열로 변환하기
a_i8 = a.astype(np.int8)
print(a_i8.dtype)
print('a_i8\n', a_i8)
# Out:
# float64
# a
#  [1. 2.]
# int8
# a_i8
#  [1 2]

# %% [markdown]
# [코드 LHR 7-6]

# %%
import numpy as np

# 자신의 학번도 포함
arr = np.array([[2024002667, 1, 2], [3, 4, 5]])

print('type(arr):', type(arr))
print('arr.ndim:', arr.ndim)
print('arr.dtype:', arr.dtype)
print('arr.size:', arr.size)
print('arr.shape:', arr.shape)
# Out:
# type(arr): <class 'numpy.ndarray'>
# arr.ndim: 2
# arr.dtype: int64
# arr.size: 6
# arr.shape: (2, 3)

# %% [markdown]
# [코드 LHR 7-7]

# %%
# !pip install pandas;
import pandas as pd

a = pd.Series([7, 8])
print(a)

b = pd.Series([10, 11], index=['a', 'b'])
print(b)
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# 0    7
# 1    8
# dtype: int64
# a    10
# b    11
# dtype: int64

# %% [markdown]
# [코드 LHR 7-8]

# %%
import pandas as pd

list1 = list([['한빛', '남자'], ['한결', '남자']])
col_names = ['이름', '성별']
pd.DataFrame(list1, columns=col_names)
# Out:
#    이름  성별
# 0  한빛  남자
# 1  한결  남자

# %% [markdown]
# [코드 LHR 7-9]

# %%
import pandas as pd

dict1 = {
    '이름': {0: '한빛', 1: '한결'},
    '성별': {0: '남자', 1: '여자'}
}

pd.DataFrame(dict1)
# Out:
#    이름  성별
# 0  한빛  남자
# 1  한결  여자

# %% [markdown]
# [코드 LHR 7-10]

# %%
import numpy as np
import pandas as pd

# 배열
arr1 = np.array([['한빛', '남자'], ['한결', '여자']])

# 열 이름 리스트
col_names = ['이름', '성별']

# 데이터프레임 생성하기
pd.DataFrame(arr1, columns=col_names)
# Out:
#    이름  성별
# 0  한빛  남자
# 1  한결  여자

# %% [markdown]
# [코드 LHR 7-11]

# %%
import pandas as pd
import numpy as np

# 리스트 데이터 생성
list1 = [
    ['이하랑', '남자'],
    ['이가원', '여자'],
    ['배규민', '남자']
]

# 열 이름 지정
col_names = ['이름', '성별']

# 데이터프레임 생성
df = pd.DataFrame(list1, columns=col_names)
df
# Out:
#     이름  성별
# 0  이하랑  남자
# 1  이가원  여자
# 2  배규민  남자

# %% [markdown]
# [코드 LHR 7-12]

# %%
# 디렉토리에 csv 파일로 저장하기
df.to_csv('LHR_seris.csv', header=True, index=False, encoding='utf-8')

# CSV 파일 읽기
df2 = pd.read_csv('LHR_seris.csv', sep=',')

# 모든 열 이름 조회
df2.columns
# Out:
# Index(['이름', '성별'], dtype='object')

# %% [markdown]
# [코드 LHR 7-13]

# %%
df2.head(1)
# Out:
#     이름  성별
# 0  이하랑  남자

# %% [markdown]
# [코드 LHR 7-14]

# %%
df[['이름']].head()
# Out:
#     이름
# 0  이하랑
# 1  이가원
# 2  배규민

# %% [markdown]
# [코드 LHR 7-15]

# %%
df.iloc[1:2, 0:1]
# Out:
#     이름
# 1  이가원

# %% [markdown]
# [코드 LHR 7-16]

# %%
df.iloc[0:1, 0:1]
# Out:
#     이름
# 0  이하랑

# %% [markdown]
# [코드 LHR 7-17]

# %%
df[df['이름'] == '배규민'].head()
# Out:
#     이름  성별
# 2  배규민  남자

# %% [markdown]
# [코드 LHR 7-18]

# %%
import pandas as pd

list1 = [
    ['자신의이름', '남자', 30, 183],
    ['이가원', '여자', 24, 162],
    ['배규민', '남자', 23, 179],
    ['고고림', '남자', 21, 182]
]

col_names = ['이름', '성별', '나이', '키']
df = pd.DataFrame(list1, columns=col_names)

df[df['키'] > 180]
# Out:
#       이름  성별  나이    키
# 0  자신의이름  남자  30  183
# 3    고고림  남자  21  182

# %% [markdown]
# [코드 LHR 7-19]

# %%
df[(df['성별'] == '여자') & (df['키'] > 160)]
# Out:
#     이름  성별  나이    키
# 1  이가원  여자  24  162

# %% [markdown]
# [코드 LHR 7-20]

# %%
df[df['이름'].str.contains('고')]
# Out:
#     이름  성별  나이    키
# 3  고고림  남자  21  182

# %% [markdown]
# [코드 LHR 7-21]

# %%
df.loc[3, '키'] = df.loc[3, '키'] + 5
df.loc[[3]]
# Out:
#     이름  성별  나이    키
# 3  고고림  남자  21  187

# %% [markdown]
# [코드 LHR 7-22]

# %%
df['보너스'] = df['나이'] * 10000
df.head(3)
# Out:
#       이름  성별  나이    키     보너스
# 0  자신의이름  남자  30  183  300000
# 1    이가원  여자  24  162  240000
# 2    배규민  남자  23  179  230000

# %% [markdown]
# [코드 LHR 7-23]

# %%
df.drop('보너스', axis=1, inplace=True)
df.head(3)
# Out:
#       이름  성별  나이    키
# 0  자신의이름  남자  30  183
# 1    이가원  여자  24  162
# 2    배규민  남자  23  179

# %% [markdown]
# [코드 LHR 7-24]

# %%
df.reset_index(inplace=True)
df.head(3)
# Out:
#    index     이름  성별  나이    키
# 0      0  자신의이름  남자  30  183
# 1      1    이가원  여자  24  162
# 2      2    배규민  남자  23  179

# %% [markdown]
# [코드 LHR 7-25]

# %%
import numpy as np

# 실수형 배열 생성하기
c = np.array([3, 5], dtype=np.float64)
print(c.dtype)
print('c\n', c)

# arange()를 사용한 배열 생성
d = np.arange(1, 18, 4)  # 1부터 15 미만까지 3씩 증가
print('\nd (arange)\n', d)
# Out:
# float64
# c
#  [3. 5.]
#
# d (arange)
#  [ 1  5  9 13 17]

# %% [markdown]
# [코드 LHR 7-26]

# %%
import pandas as pd

data = {'k': [2, 3], 'M': [5, 6]}
df5 = pd.DataFrame(data)

print(df5[0:1][0:1])
print(df5[0:2][0:2])
# Out:
#    k  M
# 0  2  5
#    k  M
# 0  2  5
# 1  3  6

# %% [markdown]
# [코드 LHR 7-27]

# %%
import pandas as pd

list1 = [
    ['홍길동', '남자', 30, 183],
    ['이가원', '여자', 24, 162],
    ['배규민', '남자', 23, 179]
]

col_names = ['이름', '성별', '나이', '키']
df = pd.DataFrame(list1, columns=col_names)

print(df.loc[[2]])
# Out:
#     이름  성별  나이    키
# 2  배규민  남자  23  179

# %% [markdown]
# [코드 LHR 7-28]

# %%
import pandas as pd

list1 = [
    ['홍길동', '남자', 30, 183],
    ['배규민', '남자', 23, 179]
]

col_names = ['이름', '성별', '나이', '키']
df = pd.DataFrame(list1, columns=col_names)

df['나이(일)'] = df['나이'] * 1000

print(df)
# Out:
#     이름  성별  나이    키  나이(일)
# 0  홍길동  남자  30  183  30000
# 1  배규민  남자  23  179  23000

# %% [markdown]
# [코드 LHR 7-29]

# %%
import pandas as pd

list1 = [
    ['홍길동', '남자', 30, 183],
    ['배규민', '남자', 23, 179]
]

col_names = ['이름', '성별', '나이', '키']
df = pd.DataFrame(list1, columns=col_names)

df.drop('성별', axis=1, inplace=True)

print(df)
# Out:
#     이름  나이    키
# 0  홍길동  30  183
# 1  배규민  23  179

# %% [markdown]
# [코드 LHR 7-30]

# %%
import pandas as pd

list1 = [
    ['홍길동', '남자', 30, 183],
    ['배규민', '여자', 23, 179]
]

col_names = ['이름', '성별', '나이', '키']
df = pd.DataFrame(list1, columns=col_names)

# '성별'이 '여자'인 행만 필터링
filtered_df = df[df['성별'] == '여자']

print(filtered_df)
# Out:
#     이름  성별  나이    키
# 1  배규민  여자  23  179
